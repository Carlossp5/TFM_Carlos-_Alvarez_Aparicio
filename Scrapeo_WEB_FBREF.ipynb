# %% [markdown]
# # **0. Cargar librerias**

# %%
import pandas as pd
pd.set_option('display.max_columns',None)

# %% [markdown]
# # **1. Extraer Datasets**

# %%
URL = {
    'LALIGA_2023_2024':'https://fbref.com/en/comps/12/La-Liga-Stats',
    'LALIGA_2022_2023':'https://fbref.com/en/comps/12/2022-2023/2022-2023-La-Liga-Stats',
    'LALIGA_2021_2022':'https://fbref.com/en/comps/12/2021-2022/2021-2022-La-Liga-Stats',
    'LALIGA_2020_2021':'https://fbref.com/en/comps/12/2020-2021/2020-2021-La-Liga-Stats',
    'LALIGA_2019_2020':'https://fbref.com/en/comps/12/2019-2020/2019-2020-La-Liga-Stats',
    'LALIGA_2018_2019':'https://fbref.com/en/comps/12/2018-2019/2018-2019-La-Liga-Stats',
    'LALIGA_2017_2018':'https://fbref.com/en/comps/12/2017-2018/2017-2018-La-Liga-Stats',
    'PREMIER_2023_2024':'https://fbref.com/en/comps/9/Premier-League-Stats',
    # 'PREMIER_2022_2023':'https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats',
    # 'PREMIER_2021_2022':'https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats',
    # 'PREMIER_2020_2021':'https://fbref.com/en/comps/9/2020-2021/2020-2021-Premier-League-Stats',
    # 'PREMIER_2019_2020':'https://fbref.com/en/comps/9/2019-2020/2019-2020-Premier-League-Stats',
    # 'PREMIER_2018_2019':'https://fbref.com/en/comps/9/2018-2019/2018-2019-Premier-League-Stats',
    # 'PREMIER_2017_2018':'https://fbref.com/en/comps/9/2017-2018/2017-2018-Premier-League-Stats',
    # 'SERIEA_2023_2024':'https://fbref.com/en/comps/11/Serie-A-Stats',
    # 'SERIEA_2022_2023':'https://fbref.com/en/comps/11/2022-2023/2022-2023-Serie-A-Stats',
    # 'SERIEA_2021_2022':'https://fbref.com/en/comps/11/2021-2022/2021-2022-Serie-A-Stats',
    # 'SERIEA_2020_2021':'https://fbref.com/en/comps/11/2020-2021/2020-2021-Serie-A-Stats',
    # 'SERIEA_2019_2020':'https://fbref.com/en/comps/11/2019-2020/2019-2020-Serie-A-Stats',
    # 'SERIEA_2018_2019':'https://fbref.com/en/comps/11/2018-2019/2018-2019-Serie-A-Stats',
    # 'SERIEA_2017_2018':'https://fbref.com/en/comps/11/2017-2018/2017-2018-Serie-A-Stats',
    # 'BUNDESLIGA_2023_2024':'https://fbref.com/en/comps/20/Bundesliga-Stats',
    # 'BUNDESLIGA_2022_2023':'https://fbref.com/en/comps/20/2022-2023/2022-2023-Bundesliga-Stats',
    # 'BUNDESLIGA_2021_2022':'https://fbref.com/en/comps/20/2021-2022/2021-2022-Bundesliga-Stats',
    # 'BUNDESLIGA_2020_2021':'https://fbref.com/en/comps/20/2020-2021/2020-2021-Bundesliga-Stats',
    # 'BUNDESLIGA_2019_2020':'https://fbref.com/en/comps/20/2019-2020/2019-2020-Bundesliga-Stats',
    # 'BUNDESLIGA_2018_2019':'https://fbref.com/en/comps/20/2018-2019/2018-2019-Bundesliga-Stats',
    # 'BUNDESLIGA_2017_2018':'https://fbref.com/en/comps/20/2017-2018/2017-2018-Bundesliga-Stats',
    # 'LIGUE1_2023_2024':'https://fbref.com/en/comps/13/Ligue-1-Stats',
    # 'LIGUE1_2022_2023':'https://fbref.com/en/comps/13/2022-2023/2022-2023-Ligue-1-Stats',
    # 'LIGUE1_2021_2022':'https://fbref.com/en/comps/13/2021-2022/2021-2022-Ligue-1-Stats',
    # 'LIGUE1_2020_2021':'https://fbref.com/en/comps/13/2020-2021/2020-2021-Ligue-1-Stats',
    # 'LIGUE1_2019_2020':'https://fbref.com/en/comps/13/2019-2020/2019-2020-Ligue-1-Stats',
    # 'LIGUE1_2018_2019':'https://fbref.com/en/comps/13/2018-2019/2018-2019-Ligue-1-Stats',
    # 'LIGUE1_2017_2018':'https://fbref.com/en/comps/13/2017-2018/2017-2018-Ligue-1-Stats',
    }

# %%
names_list = pd.Series(URL).index.tolist()
url_list = pd.Series(URL).tolist()
lista_datasets = ['Clasificacion_Home_Away','Standard_Stats','Opponent_Standard_Stats',
                  'Squad_Goalkeeping','Squad_Goalkeeping_Opponent_Stats','Squad_Advance_Goalkeeping','Squad_Advance_Goalkeeping_Opponent_Stats',
                  'Shooting_Stats','Shooting_Opponent_Stats','Passing_Stats','Passing_Opponent_Stats',
                  'Pass_Types_Stats','Pass_Types_Opponent_Stats','Goal_Shot_Creation_Stats','Goal_Shot_Creation_Opponent_Stats',
                  'Defensive_Stats','Defensive_Opponent_Stats','Possession_Stats','Possession_Opponent_Stats',
                  'Playing_Time_Stats','Playing_Time_Opponent_Stats','Miscelanious_Stats','Miscelanious_Opponent_Stats']

# %%
tables_ligas = {}

# Iterar sobre las listas
for name, url in zip(names_list, url_list):
    # Leer las tablas desde la URL
    tables_0 = pd.read_html(url, header=0)
    tables = pd.read_html(url, header=1)
    tables_ligas['Clasificacion' + '_' + name] = tables_0[0]

    for nombre_df, tabla in zip(lista_datasets, tables[1:]):
        # Asignar nombres a las tablas en el diccionario
        tables_ligas[nombre_df + '_' + name] = tabla

# %%
print("Claves del diccionario:", tables_ligas.keys())
# Out:
# Claves del diccionario: dict_keys(['Clasificacion_LALIGA_2023_2024', 'Clasificacion_Home_Away_LALIGA_2023_2024', 'Standard_Stats_LALIGA_2023_2024', 'Opponent_Standard_Stats_LALIGA_2023_2024', 'Squad_Goalkeeping_LALIGA_2023_2024', 'Squad_Goalkeeping_Opponent_Stats_LALIGA_2023_2024', 'Squad_Advance_Goalkeeping_LALIGA_2023_2024', 'Squad_Advance_Goalkeeping_Opponent_Stats_LALIGA_2023_2024', 'Shooting_Stats_LALIGA_2023_2024', 'Shooting_Opponent_Stats_LALIGA_2023_2024', 'Passing_Stats_LALIGA_2023_2024', 'Passing_Opponent_Stats_LALIGA_2023_2024', 'Pass_Types_Stats_LALIGA_2023_2024', 'Pass_Types_Opponent_Stats_LALIGA_2023_2024', 'Goal_Shot_Creation_Stats_LALIGA_2023_2024', 'Goal_Shot_Creation_Opponent_Stats_LALIGA_2023_2024', 'Defensive_Stats_LALIGA_2023_2024', 'Defensive_Opponent_Stats_LALIGA_2023_2024', 'Possession_Stats_LALIGA_2023_2024', 'Possession_Opponent_Stats_LALIGA_2023_2024', 'Playing_Time_Stats_LALIGA_2023_2024', 'Playing_Time_Opponent_Stats_LALIGA_2023_2024', 'Miscelanious_Stats
# ...

# %% [markdown]
# # **2.Clean Data**

# %%
tables_ligas.keys()

# %%
# Creo la variable temporada
for key, df in tables_ligas.items():
    last_9_chars = key[-9:]
    df = df.assign(Temporada=last_9_chars)
    tables_ligas[key] = df

# %%
tables_ligas = {key: value for key, value in tables_ligas.items() if 'Playing_Time' not in key}

# %%
for df_name in tables_ligas:
    if 'Playing_Time' in df_name:
      tables_ligas[df_name].drop(columns=['Attendance','Top Team Scorer','Goalkeeper','Notes'], inplace=True)
    elif 'Clasificacion_L' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['Attendance','Top Team Scorer','Goalkeeper','Notes'], inplace=True)
      if 'Last 5' in tables_ligas[df_name].columns:
        tables_ligas[df_name].drop(columns=['Last 5'], inplace=True)
    elif 'Clasificacion_Home_Away_' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          "Rk":"Rk_Home",
          "MP":"Partidos_Home",
          "W":"W_Home",
          "D":"D_Home",
          "L":"L_Home",
          "GF":"GF_Home",
          "GA":"GA_Home",
          "GD":"GD_Home",
          "Pts":"Pts_Home",
          "Pts/MP":"Pts_Partido_Home",
          "xG":"xG_Home",
          "xGA":"xGA_Home",
          "xGD":"xGD_Home",
          "xGD/90":"xGD/90_Home",
          "MP.1":"Partidos_Away",
          "W.1":"W_Away",
          "D.1":"D_Away",
          "L.1":"L_Away",
          "GF.1":"GF_Away",
          "GA.1":"GA_Away",
          "GD.1":"GD_Away",
          "Pts.1":"Pts_Away",
          "Pts/MP.1":"Pts_Partido_Away",
          "xG.1":"xG_Away",
          "xGA.1":"xGA_Away",
          "xGD.1":"xGD_Away",
          "xGD/90.1":"xGD/90_Away"
      }, inplace=True)
    elif 'Standard_Stats_' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['MP','Starts','Min','90s','Gls','xG','G+A-PK','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          "# Pl":"Jugadores_Involucrados",
          "Age":"Age_media",
          "Poss":"Posesion_media",
          "G-PK":"Goles_Sin_Penaltis",
          "PKatt":"Penaltis_Intentados",
          "CrdY":"Tarjetas_Amarillas",
          "CrdR":"Tarjetas_Rojas",
          'xAG':'xAst',
          'PrgC':'Prog_con_Conduccion',
          'PrgP':'Prog_con_Pase',
          'Gls.1':'Gls/90',
          'Ast.1':'Ast/90',
          'G-PK.1':'G-PK/90',
          'xG.1':'xG/90',
          'xAG.1':'xAst/90',
          'xG+xAG':'xG+xAG/90',
          'npxG.1':'npxG/90',
          'npxG+xAG.1':'npxG+xAst/90'
      }, inplace=True)
    elif 'Standard_Opponent_Stats_' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','MP','Starts','Min','90s','Gls','xG','G+A-PK','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          "Age":"Age_media_rival",
          "G+A":"G+A_rival",
          'Ast':'Ast_rival',
          "Poss":"Posesion_media_rival",
          "G-PK":"Goles_Sin_Penaltis_rival",
          'PK':'PK_rival',
          "PKatt":"Penaltis_Intentados_rival",
          "CrdY":"Tarjetas_Amarillas_rival",
          "CrdR":"Tarjetas_Rojas_rival",
          'xAG':'xAst_rival',
          'PrgC':'Prog_con_Conduccion_rival',
          'PrgP':'Prog_con_Pase_rival',
          'Gls.1':'Gls/90_rival',
          'Ast.1':'Ast/90_rival',
          'G-PK.1':'G-PK/90_rival',
          'xG.1':'xG/90_rival',
          'xAG.1':'xAst/90_rival',
          'xG+xAG':'xG+xAG/90_rival',
          'npxG.1':'npxG/90_rival',
          'npxG+xAG.1':'npxG+xAst/90_rival'
        }, inplace=True)
    elif 'Squad_Goalkeeping_L' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['MP','Starts','Min','90s','GA','W','D','L','PKatt','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          "# Pl":"Porteros_Participado",
          "GA90":"GA/90",
          'Save%.1':'Penaltis_Save%'
        }, inplace=True)
    elif 'Squad_Goalkeeping_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','MP','Starts','Min','90s','GA','W','D','L','PKatt','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'SoTA':'SoT',
          "Saves":"SoT_Detenidos_en_contra",
          'Save%':'Porc_SoT_Detenidos_en_contra',
          'PKsv':'PK_Detenidos_en_contra',
          'Save%.1':'Porc_PK_Detenidos_en_contra',
          'PKm':'PK_tirados_fuera'
        }, inplace=True)
    elif 'Squad_Goalkeeping_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','GA','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'FK':'Goles_FK_en_contra',
          "CK":"Goles_CK_en_contra",
          'OG':'Goles_en_propia',
          '/90':'PSxG_por_partido_en_contra',
          'Cmp':'Pases_Largos_Completados_Portero',
          'Att':'Pases_Largos_Intentados_Portero',
          'Cmp%':'Porc_Pases_Largos_Completados_Portero',
          'Cmp':'Pases_Completados_Portero',
          'Att (GK)':'Pases_Intentados_Portero',
          'Launch%':'Porc_Pases_Largos_Portero',
          'AvgLen':'Longitud_Media_Portero',
          'Att.1':'Saques_Puerta',
          'Launch%.1':'Porc_Saques_Puerta_Largo',
          'AvgLen.1':'Longitud_Media_Saque_Puerta',
          'Opp':'Centros_Recibidos',
          'Stp':'Centros_Detenidos_PT',
          'Stp%':'Porc_Centros_Detenidos_PT',
          '#OPA':'Acciones_Fuera_Area',
          '#OPA/90':'Acciones_Fuera_Area_Por_Partido',
          'AvgDist':'Distancia_Media_PT_Porteria'
      }, inplace=True)
    elif 'Squad_Advance_Goalkeeping_L' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','GA','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'FK':'Goles_FK_en_contra',
          "CK":"Goles_CK_en_contra",
          'OG':'Goles_en_propia',
          '/90':'PSxG_por_partido_en_contra',
          'Cmp':'Pases_Largos_Completados_Portero',
          'Att':'Pases_Largos_Intentados_Portero',
          'Cmp%':'Porc_Pases_Largos_Completados_Portero',
          'Cmp':'Pases_Completados_Portero',
          'Att (GK)':'Pases_Intentados_Portero',
          'Launch%':'Porc_Pases_Largos_Portero',
          'AvgLen':'Longitud_Media_Portero',
          'Att.1':'Saques_Puerta',
          'Launch%.1':'Porc_Saques_Puerta_Largo',
          'AvgLen.1':'Longitud_Media_Saque_Puerta',
          'Opp':'Centros_Recibidos',
          'Stp':'Centros_Detenidos_PT',
          'Stp%':'Porc_Centros_Detenidos_PT',
          '#OPA':'Acciones_Fuera_Area',
          '#OPA/90':'Acciones_Fuera_Area_Por_Partido',
          'AvgDist':'Distancia_Media_PT_Porteria'
      }, inplace=True)
    elif 'Squad_Advance_Goalkeeping_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','GA','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'FK':'Goles_FK_a_favor',
          "CK":"Goles_CK_a_favor",
          'OG':'Goles_en_propia_del_rival',
          'PSxG':'PSxG_a_favor',
          'PSxG/SoT':'PSxG/SoT_a_favor',
          'PSxG+/-':'PSxG+/-_a_favor',
          '/90':'PSxG_por_partido_a_favor',
          'Cmp':'Pases_Largos_Completados_Portero_rival',
          'Att':'Pases_Largos_Intentados_Portero_rival',
          'Cmp%':'Porc_Pases_Largos_Completados_Portero_rival',
          'Cmp':'Pases_Completados_Portero_rival',
          'Att (GK)':'Pases_Intentados_Portero_rival',
          'Launch%':'Porc_Pases_Largos_Portero_rival',
          'AvgLen':'Longitud_Media_Portero_rival',
          'Att.1':'Saques_Puerta_rival',
          'Launch%.1':'Porc_Saques_Puerta_Largo_rival',
          'AvgLen.1':'Longitud_Media_Saque_Puerta_rival',
          'Opp':'Centros_Colgados_a_favor',
          'Stp':'Centros_Detenidos_PT_rival',
          'Stp%':'Porc_Centros_Detenidos_PT_rival',
          '#OPA':'Acciones_Fuera_Area_PT_rival',
          '#OPA/90':'Acciones_Fuera_Area_PT_rival_Por_Partido',
          'AvgDist':'Distancia_Media_PT_rival_Porteria'
      }, inplace=True)
    elif 'Squad_Advance_Goalkeeping_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','GA','PKA','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'FK':'Goles_FK_a_favor',
          "CK":"Goles_CK_a_favor",
          'OG':'Goles_en_propia_del_rival',
          'PSxG':'PSxG_a_favor',
          'PSxG/SoT':'PSxG/SoT_a_favor',
          'PSxG+/-':'PSxG+/-_a_favor',
          '/90':'PSxG_por_partido_a_favor',
          'Cmp':'Pases_Largos_Completados_Portero_rival',
          'Att':'Pases_Largos_Intentados_Portero_rival',
          'Cmp%':'Porc_Pases_Largos_Completados_Portero_rival',
          'Cmp':'Pases_Completados_Portero_rival',
          'Att (GK)':'Pases_Intentados_Portero_rival',
          'Launch%':'Porc_Pases_Largos_Portero_rival',
          'AvgLen':'Longitud_Media_Portero_rival',
          'Att.1':'Saques_Puerta_rival',
          'Launch%.1':'Porc_Saques_Puerta_Largo_rival',
          'AvgLen.1':'Longitud_Media_Saque_Puerta_rival',
          'Opp':'Centros_Colgados_a_favor',
          'Stp':'Centros_Detenidos_PT_rival',
          'Stp%':'Porc_Centros_Detenidos_PT_rival',
          '#OPA':'Acciones_Fuera_Area_PT_rival',
          '#OPA/90':'Acciones_Fuera_Area_PT_rival_Por_Partido',
          'AvgDist':'Distancia_Media_PT_rival_Porteria'
      }, inplace=True)
    elif 'Shooting_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','xG','90s','Gls','Sh','SoT','SoT%','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'Sh':'Tiros_a_favor',
          "Sh/90":"Tiros_a_favor_por_partido",
          'SoT/90':'Tiros_a_puerta_a_favor_por_partido',
          'G/Sh':'Goles_por_disparo_a_favor',
          'G/SoT':'Goles_por_disparo_a_puerta',
          'PSxG/SoT':'Goles_por_disparo_a_puerta_a_favor',
          'Dist':'Distancia_media_tiros',
          'FK':'Tiros_FK_a_favor',
          'PK':'Penaltis_Realizados_en_contra',
          'PKAtt':'Penaltis_intentados_a_favor',
          'npxG':'xG_sin_penaltis',
          'npxG/Sh':'xG_sin_penaltis_por_tiro',
          'np:G-xG':'Goles_sin_penaltis_menos_xG_sin_penaltis'
      }, inplace=True)
    elif 'Shooting_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','Gls','SoT','SoT%','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'Sh':'Tiros_en_contra',
          "Sh/90":"Tiros_en_contra_por_partido",
          'SoT/90':'Tiros_a_puerta_en_contra_por_partido',
          'G/Sh':'Goles_por_disparo_en_contra',
          'G/SoT':'Goles_por_disparo_en_contra',
          'PSxG/SoT':'Goles_por_disparo_a_puerta_en_contra',
          'Dist':'Distancia_media_tiros_en_contra',
          'FK':'Tiros_FK_en_contra',
          'PKatt':'Penaltis_intentados_en_contra',
          'xG':'xG_en_contra',
          'npxG/Sh':'xG_en_contra_sin_penaltis_por_tiro',
          'np:G-xG':'Goles_sin_penaltis_menos_xG_sin_penaltis_en_contra'
      }, inplace=True)
    elif 'Shooting_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','Gls','SoT','SoT%','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'Sh':'Tiros_en_contra',
          "Sh/90":"Tiros_en_contra_por_partido",
          'SoT/90':'Tiros_a_puerta_en_contra_por_partido',
          'G/Sh':'Goles_por_disparo_en_contra',
          'G/SoT':'Goles_por_disparo_en_contra',
          'PSxG/SoT':'Goles_por_disparo_a_puerta_en_contra',
          'Dist':'Distancia_media_tiros_en_contra',
          'FK':'Tiros_FK_en_contra',
          'PKatt':'Penaltis_intentados_en_contra',
          'xG':'xG_en_contra',
          'npxG/Sh':'xG_en_contra_sin_penaltis_por_tiro',
          'np:G-xG':'Goles_sin_penaltis_menos_xG_sin_penaltis_en_contra'
      }, inplace=True)
    elif 'Passing_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','Ast','xAG','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'Cmp':'Pases_Completados_a_favor',
          "Att":"Pases_Intentados_a_favor",
          'Cmp%':'Porc_Pases_Completados_a_favor',
          'TotDist':'Distancia_recorrida_pases_a_favor',
          'PrgDist':'Distancia_progresada_a_favor',
          'Cmp.1':'Pases_Cortos_Completados_a_favor',
          'Att.1':'Pases_Cortos_Intentados_a_favor',
          'Cmp%.1':'Porc_Pases_Cortos_Completados_a_favor',
          'Cmp.2':'Pases_Medios_Completados_a_favor',
          'Att.2':'Pases_Medios_Intentados_a_favor',
          'Cmp%.2':'Porc_Pases_Medios_Completados_a_favor',
          'Cmp.3':'Pases_Largos_Completados_a_favor',
          'Att.3':'Pases_Largos_Intentados_a_favor',
          'Cmp%.3':'Porc_Pases_Largos_Completados_a_favor',
          'xA':'xAst_2_a_favor',
          'KP':'Pases_Clave_a_favor',
          '1/3':'Pases_Primer_Tercio_a_favor',
          'PPA':'Pases_Area_Penalti_a_favor',
          'CrsPA':'Centros_Area_a_favor',
          'PrgP':'Pases_Progresivos_a_favor'
      }, inplace=True)
    elif 'Passing_Opponent_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','Ast','xAG','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'Cmp':'Pases_Completados_en_contra',
          "Att":"Pases_Intentados_en_contra",
          'Cmp%':'Porc_Pases_Completados_en_contra',
          'TotDist':'Distancia_recorrida_pases__en_contra',
          'PrgDist':'Distancia_progresada_en_contra',
          'Cmp.1':'Pases_Cortos_Completados_en_contra',
          'Att.1':'Pases_Cortos_Intentados_en_contra',
          'Cmp%.1':'Porc_Pases_Cortos_Completados_en_contra',
          'Cmp.2':'Pases_Medios_Completados_en_contra',
          'Att.2':'Pases_Medios_Intentados_en_contra',
          'Cmp%.2':'Porc_Pases_Medios_Completados_en_contra',
          'Cmp.3':'Pases_Largos_Completados_en_contra',
          'Att.3':'Pases_Largos_Intentados_en_contrar',
          'Cmp%.3':'Porc_Pases_Largos_Completados_en_contra',
          'xA':'xAst_2_en_contra',
          'KP':'Pases_Clave_en_contra',
          '1/3':'Pases_Primer_Tercio_en_contra',
          'PPA':'Pases_Area_Penalti_en_contra',
          'CrsPA':'Centros_Area_en_contra',
          'PrgP':'Pases_Progresivos_en_contra'
      }, inplace=True)
    elif 'Pass_Types_Stats' in df_name:
      print(df_name)
      tables_ligas[df_name].drop(columns=['# Pl','90s','Att','Live','Dead','TI','Cmp','Temporada'], inplace=True)
      tables_ligas[df_name].rename(columns={
          'TB':'Pases_Espalda_Defensa_a_favor',
          'Sw':'Cambios_Orientacion_a_favor',
          'Crs':'Centros_a_favor',
          'CK':'Saques_Esquina_a_favor',
          'In':'Saques_Esquina_Interior_Area_a_favor',
          'Out':'Saques_Esquina_Exterior_Area_a_favor',
          'Str':'Saques_Esquina_Directo_Area_a_favor',
          'Off':'Pases_a_favor_Fuera_Juego',
          'Blocks':'Pases_Bloqueados_en_contra'
        }, inplace=True)
    elif 'Pass_Types_Opponent_Stats' in df_name:
       print(df_name)
       tables_ligas[df_name].drop(columns=['# Pl','90s','Att','Live','Dead','TI','Cmp','Temporada'], inplace=True)
       tables_ligas[df_name].rename(columns={
          'FK':'FK_en_contra',
          'TB':'Pases_Espalda_Defensa_en_contra',
          'Sw':'Cambios_Orientacion_en_contra',
          'Crs':'Centros_en_contra',
          'CK':'Saques_Esquina_en_contra',
          'In':'Saques_Esquina_Interior_Area_en_contra',
          'Out':'Saques_Esquina_Exterior_Area_en_contra',
          'Str':'Saques_Esquina_Directo_Area_en_contra',
          'Off':'Pases_Fuera_Juego_en_contra',
          'Blocks':'Pases_Bloqueados_en_contra'
        }, inplace=True)
    elif 'Goal_Shot_Creation_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','PassLive','PassDead','PassLive.1','PassDead.1','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'SCA':'Accion_Tiro_Creada_a_favor',
            'SCA90':'Accion_Tiro_Creada_por_Partido_a_favor',
            'TO':'Regates_ante_Tiro_a_favor',
            'Sh':'Tiros_Generado_tras_Rebote_a_favor',
            'Fld':'Faltas_para_Disparar_a_favor',
            'Def':'Acciones_Defensivas_Preceden_Tiro_a_favor',
            'GCA':'Acciones_Creadas_Gol_a_favor',
            'GCA90':'Acciones_Creadas_Gol_por_partido_a_favor',
            'TO.1':'Regates_ante_Gol_a_favor',
            'Sh.1':'Gol_Generado_tras_Rebote_a_favor',
            'Fld.1':'Goles_Falta_para_Disparar_a_favor',
            'Def.1':'Acciones_Defensivas_Preceden_Gol_a_favor',
        }, inplace=True)
    elif 'Goal_Shot_Creation_Opponent_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','PassLive','PassDead','PassLive.1','PassDead.1','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'SCA':'Accion_Tiro_Creada_en_contra',
            'SCA90':'Accion_Tiro_Creada_por_Partido_en_contra',
            'TO':'Regates_ante_Tiro_en_contra',
            'Sh':'Tiros_Generado_tras_Rebote_en_contra',
            'Fld':'Faltas_para_Disparar_en_contra',
            'Def':'Acciones_Defensivas_Preceden_Tiro_en_contra',
            'GCA':'Acciones_Creadas_Gol_en_contra',
            'GCA90':'Acciones_Creadas_Gol_por_partido_en_contra',
            'TO.1':'Regates_ante_Gol_en_contra',
            'Sh.1':'Gol_Generado_tras_Rebote_en_contra',
            'Fld.1':'Goles_Falta_para_Disparar_en_contra',
            'Def.1':'Acciones_Defensivas_Preceden_Gol_en_contra',
        }, inplace=True)
    elif 'Defensive_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Lost','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'Tkl':'Tackle_a_favor',
            'TklW':'Tacle_Ganado_a_favor',
            'Def 3rd':'Tackle_1_Tercio_a_favor',
            'Mid 3rd':'Tackle_2_Tercio_a_favor',
            'Att 3rd':'Tackle_3_Tercio_a_favor',
            'Tkl.1':'Tackle_Regalte_a_favor',
            'Att':'Tackle_Regate_Intentados_a_favor',
            'Tkl%':'Porc_Tackle_Ganado_a_favor',
            'Blocks':'Bloqueos_a_favor',
            'Sh':'Tiros_Bloqueos_a_favor',
            'Pass':'Pases_Bloqueos_a_favor',
            'Int':'Interceptaciones_a_favor',
            'Tkl+Int':'Tackles_Interceptaciones_a_favor',
            'Clr':'Despejes_a_favor',
            'Err':'Errores_equipo_propio'
        }, inplace=True)
    elif 'Defensive_Opponent_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Lost','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'Tkl':'Tackle_a_favor',
            'TklW':'Tacle_Ganado_a_favor',
            'Def 3rd':'Tackle_1_Tercio_a_favor',
            'Mid 3rd':'Tackle_2_Tercio_a_favor',
            'Att 3rd':'Tackle_3_Tercio_a_favor',
            'Tkl.1':'Tackle_Regalte_a_favor',
            'Att':'Tackle_Regate_Intentados_a_favor',
            'Tkl%':'Porc_Tackle_Ganado_a_favor',
            'Blocks':'Bloqueos_a_favor',
            'Sh':'Tiros_Bloqueos_a_favor',
            'Pass':'Pases_Bloqueos_a_favor',
            'Int':'Interceptaciones_a_favor',
            'Tkl+Int':'Tackles_Interceptaciones_a_favor',
            'Clr':'Despejes_a_favor',
            'Err':'Errores_equipo_propio'
        }, inplace=True)
    elif 'Possession_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Live','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'Poss':'Posesion_a_favor',
            'Touches':'Toques_a_favor',
            'Def Pen':'Toques_en_area_propia_a_favor',
            'Def 3rd':'Toques_en_primer_tercio_a_favor',
            'Mid 3rd':'Toques_en_segundo_tercio_a_favor',
            'Att 3rd':'Toques_en_tercer_tercio_a_favor',
            'Att Pen':'Toques_en_tarea_rival_a_favor',
            'Att':'Regate_Intentados_a_favor',
            'Succ':'Regates_Completados_a_favor',
            'Succ%':'Porc_Regates_Completados_a_favor',
            'Tkld':'Tackles_Regate_en_contra',
            'Tkld%':'Porcentaje_Tackles_Regate_en_contra',
            'Carries':'Conduccioness_a_favor',
            'TotDist':'Distancia_Recorrida_por_Balon_a_favor',
            'PrgDist':'Distancia_Recorrida_por_Balon_Adelante_a_favor',
            'PrgC':'Toques_Balon_Adelante_a_favor',
            '1/3':'Conducciones_Ultimo_Tercio_a_favor',
            'CPA':'Conducciones_Area_Penalti_a_favor',
            'Mis':'Fallos_de_Control_equipo_propio',
            'Dis':'Perdida_Balon_euipo_propio_por_Tackle',
            'Rec':'Pases_Recibidos_a_favor',
            'PrgR':'Pases_Progresivos_Recibidos_a_favor'
        }, inplace=True)
    elif 'Possession_Opponent_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Live','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'Poss':'Posesion_en_contra',
            'Touches':'Toque_en_contra',
            'Def Pen':'Toques_en_area_rival_en_contra',
            'Def 3rd':'Toques_en_primer_tercio_rival_en_contra',
            'Mid 3rd':'Toques_en_segundo_tercio_rival_en_contra',
            'Att 3rd':'Toques_en_tercer_tercio_rival_en_contra',
            'Att Pen':'Toques_en_area_propia_en_contra',
            'Att':'Regate_Intentados_en_contra',
            'Succ':'Regates_Completados_en_contra',
            'Succ%':'Porc_Regates_Completados_en_contra',
            'Tkld':'Tackles_Regate_a_favor',
            'Tkld%':'Porcentaje_Tackles_Regate_a_favor',
            'Carries':'Conduccioness_en_contra',
            'TotDist':'Distancia_Recorrida_por_Balon_en_contra',
            'PrgDist':'Distancia_Recorrida_por_Balon_Adelante_en_contra',
            'PrgC':'Toques_Balon_Adelante_en_contra',
            '1/3':'Conducciones_Ultimo_Tercio_en_contra',
            'CPA':'Conducciones_Area_Penalti_en_contra',
            'Mis':'Fallos_de_Control_equipo_rival',
            'Dis':'Perdida_Balon_euipo_rival_por_Tackle',
            'Rec':'Pases_Recibidos_en_contra',
            'PrgR':'Pases_Progresivos_Recibidos_en_contra'
        }, inplace=True)
    elif 'Miscelanious_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Fld','Crs','Int','TklW','PKwon','PKcon','OG','Recov','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'CrdY':'Tarjetas_Amarillas_equipo_propio',
            'CrdR':'Tarjetas_Rojas_equipo_propio',
            '2CrdY':'2_Tarjetas_Amarillas_equipo_propio',
            'Fls':'Faltas_cometidas_equipo_propio',
            'Off':'Fueras_Juego_equipo_propio',
            'Won':'Duelos_Aereos_ganados_equipo_propio',
            'Lost':'Duelos_Aereos_perdidos_equipo_propio',
            'Won%':'Porc_Duelos_Aereos_ganados_equipo_propio'
        }, inplace=True)
    elif 'Miscelanious_Opponent_Stats' in df_name:
        print(df_name)
        tables_ligas[df_name].drop(columns=['# Pl','90s','Fld','Crs','Int','TklW','PKwon','PKcon','OG','Recov','Temporada'], inplace=True)
        tables_ligas[df_name].rename(columns={
            'CrdY':'Tarjetas_Amarillas_equipo_propio',
            'CrdR':'Tarjetas_Rojas_equipo_propio',
            '2CrdY':'2_Tarjetas_Amarillas_equipo_propio',
            'Fls':'Faltas_cometidas_equipo_propio',
            'Off':'Fueras_Juego_equipo_propio',
            'Won':'Duelos_Aereos_ganados_equipo_propio',
            'Lost':'Duelos_Aereos_perdidos_equipo_propio',
            'Won%':'Porc_Duelos_Aereos_ganados_equipo_propio'
        }, inplace=True)

# %% [markdown]
# ## Juntar los Datasets

# %%
# Crear un diccionario para almacenar los DataFrames fusionados con sufijo
result_dict = {}

# DISTINGO LAS TABLAS POR LIGA Y AÑO
for liga_anio in names_list:
    tables_Prop = {}
    for df_name in tables_ligas.keys():
        if (liga_anio in df_name) and ('Opponent_' not in df_name):
            tables_Prop[df_name] = tables_ligas[df_name]
    tables_Opp = {}
    for df_name in tables_ligas.keys():
        if (liga_anio in df_name) and ('Opponent_' in df_name):
            tables_Opp[df_name] = tables_ligas[df_name]

    merged_df = None

    # Iterar sobre las claves del diccionario
    for df_name in tables_Prop.keys():
        df = tables_Prop[df_name]

        # Fusionar el DataFrame actual con el DataFrame acumulado
        if merged_df is None:
            merged_df = df
        else:
            merged_df = merged_df.merge(df, on='Squad', how='inner')

    # Agregar el DataFrame fusionado a la lista
    Df_Propia = merged_df.copy()

    merged_df = None

    # Iterar sobre las claves del diccionario
    for df_name in tables_Opp.keys():
        df = tables_Opp[df_name]

        # Fusionar el DataFrame actual con el DataFrame acumulado
        if merged_df is None:
            merged_df = df
        else:
            merged_df = merged_df.merge(df, on='Squad', how='inner')

    # Agregar el DataFrame fusionado a la lista
    Df_Opponent = merged_df.copy()

    Df_Opponent['Squad'] = Df_Opponent['Squad'].str.replace('vs ', '')
    Df_Season_Total = Df_Propia.merge(Df_Opponent, how='inner', on='Squad')

    # Agregar el DataFrame fusionado al diccionario con sufijo
    result_dict[liga_anio] = Df_Season_Total

# %%
names_list
# Out:
# ['LALIGA_2023_2024',
#  'LALIGA_2022_2023',
#  'LALIGA_2021_2022',
#  'LALIGA_2020_2021',
#  'LALIGA_2019_2020',
#  'LALIGA_2018_2019',
#  'LALIGA_2017_2018']

# %%
DF_FINAL = pd.DataFrame()
for df_name in names_list:
    if df_name in result_dict:
        DF_FINAL = pd.concat([DF_FINAL, result_dict[df_name]], axis=0)
    else:
        print(f"DataFrame {df_name} not found in result_dict.")

# Reset index if needed
DF_FINAL.reset_index(drop=True, inplace=True)

# %%
DF_FINAL.shape

# %%
DF_FINAL.rename(columns={'Jugadores_Involucrados_x':'Jugadores_Involucrados',
                         'Age_media_x':'Age_media_equipo_propio',
                         'Posesion_media_x':'Posesion_media_a_favor ',
                         'Ast_x':'Ast_a_favor',
                         'G+A_x':'G+A_a_favor',
                         'Goles_Sin_Penaltis_x':'Goles_Sin_Penaltis_a_favor',
                         'Penaltis_Intentados_x':'Penaltis_Intentados_a_favor',
                         'Tarjetas_Amarillas_x':'Tarjetas_Amarillas_propias',
                         'Tarjetas_Rojas_x':'Tarjetas_Rojas_propias',
                         'xAst_x':'xAst_a_favor',
                         'npxG+xAG_x':'npxG+xAG_a_favor',
                         'Prog_con_Conduccion_x':'Prog_con_Conduccion_a_favor',
                         'Prog_con_Pase_x':'Prog_con_Pase_a_favor',
                         'Gls/90_x':'Gls/90_a_favor',
                         'Ast/90_x':'Ast/90_a_favor',
                         'G+A.1_x':'G+A.1_a_favor',
                         'G-PK/90_x':'G-PK/90_a_favor',
                         'xG/90_x':'xG/90_a_favor',
                         'xAst/90_x':'xAst/90_a_favor',
                         'xG+xAG/90_x':'xG+xAG/90_a_favor',
                         'npxG/90_x':'npxG/90_a_favor',
                         'npxG+xAst/90_x':'npxG+xAst/90_a_favor',
                         'CS_x':'CS_a_favor',
                         'CS%_x':'CS%_a_favor',
                         'Thr_x':'Centros_Interceptados_a_favor',
                         'G-xG_x':'G-xG_a_favor',
                         'A-xAG_x':'A-xAG_a_favor',
                         'Pases_Bloqueados_en_contra_x':'Pases_Bloqueados_por_rival',
                         'Tackle_a_favor_x':'Tackle_a_favor',
                         'Tacle_Ganado_a_favor_x':'Tackle_Ganado_a_favor',
                         'Tackle_1_Tercio_a_favor_x':'Tackle_1_Tercio_a_favor',
                         'Tackle_2_Tercio_a_favor_x':'Tackle_2_Tercio_a_favor',
                         'Tackle_3_Tercio_a_favor_x':'Tackle_3_Tercio_a_favor',
                         'Tackle_Regate_a_favor_x':'Tackle_Regate_a_favor',
                         'Tackle_Regate_Intentados_a_favor_x':'Tackle_Regate_Intentados_a_favor',
                         'Porc_Tackle_Ganado_a_favor_x':'Porc_Tackle_Ganado_a_favor',
                         'Bloqueos_a_favor_x':'Bloqueos_a_favor',
                         'Tiros_Bloqueos_a_favor_x':'Tiros_Bloqueos_a_favor',
                         'Pases_Bloqueos_a_favor_x':'Pases_Bloqueos_a_favor',
                         'Interceptaciones_a_favor_x':'Interceptaciones_a_favor',
                         'Tackles_Interceptaciones_a_favor_x':'Tackles_Interceptaciones_a_favor',
                         'Despejes_a_favor_x':'Despejes_a_favor',
                         'Errores_equipo_propio_x':'Errores_equipo_propio',
                         'Tarjetas_Amarillas_equipo_propio_x':'Eliminar_1',
                         'Tarjetas_Rojas_equipo_propio_x':'Eliminar_2',
                         '2_Tarjetas_Amarillas_equipo_propio_x':'2_Tarjetas_Amarillas_equipo_propio',
                         'Faltas_cometidas_equipo_propio_x':'Faltas_cometidas_equipo_propio',
                         'Fueras_Juego_equipo_propio_x':'Fueras_Juego_equipo_propio',
                         'Duelos_Aereos_ganados_equipo_propio_x':'Duelos_Aereos_ganados_equipo_propio',
                         'Duelos_Aereos_perdidos_equipo_propio_x':'Duelos_Aereos_perdidos_equipo_propio',
                         'Porc_Duelos_Aereos_ganados_equipo_propio_x':'Porc_Duelos_Aereos_ganados_equipo_propio'
                         }, inplace=True)
DF_FINAL.drop(columns=['Eliminar_1','Eliminar_2'], inplace=True)

# %%
DF_FINAL.rename(columns={'Jugadores_Involucrados_y':'Eliminar_1',
                         'Age_media_y':'Age_media_equipos_rivales',
                         'Posesion_media_y':'Posesion_media_en_contra',
                         'Ast_y':'Ast_en_contra',
                         'G+A_y':'G+A_en_contra',
                         'Goles_Sin_Penaltis_y':'Goles_Sin_Penaltis_en_contra',
                         'Penaltis_Intentados_y':'Penaltis_Intentados_en_contra',
                         'Tarjetas_Amarillas_y':'Tarjetas_Amarillas_en_contra',
                         'Tarjetas_Rojas_y':'Tarjetas_Rojas_en_contra',
                         'xAst_y':'xAst_en_contra',
                         'npxG+xAG_y':'npxG+xAG_en_contra',
                         'Prog_con_Conduccion_y':'Prog_con_Conduccion_en_contra',
                         'Prog_con_Pase_y':'Prog_con_Pase_en_contra',
                         'Gls/90_y':'Gls/90__en_contra',
                         'Ast/90_y':'Ast/90__en_contra',
                         'G+A.1_y':'G+A.1__en_contra',
                         'G-PK/90_y':'G-PK/90__en_contra',
                         'xG/90_y':'xG/90__en_contra',
                         'xAst/90_y':'xAst/90__en_contra',
                         'xG+xAG/90_y':'xG+xAG/90__en_contra',
                         'npxG/90_y':'npxG/90__en_contra',
                         'npxG+xAst/90_y':'npxG+xAst/90__en_contra',
                         'CS_y':'CS__en_contra',
                         'CS%_y':'CS%__en_contra',
                         'Thr_y':'Centros_Interceptados_en_contra',
                         'G-xG_y':'G-xG__en_contra',
                         'A-xAG_y':'A-xAG__en_contra',
                         'Pases_Bloqueados_en_contra_y':'Pases_Bloqueados_por_equipo_propio',
                         'Tackle_a_favor_y':'Tackle_en_contra',
                         'Tacle_Ganado_a_favor_y':'Tackle_Ganado_en_contra',
                         'Tackle_1_Tercio_a_favor_y':'Tackle_1_Tercio_en_contra',
                         'Tackle_2_Tercio_a_favor_y':'Tackle_2_Tercio_en_contra',
                         'Tackle_3_Tercio_a_favor_y':'Tackle_3_Tercio_en_contra',
                         'Tackle_Regate_a_favor_y':'Tackle_Regate_en_contra',
                         'Tackle_Regate_Intentados_a_favor_y':'Tackle_Regate_Intentados_en_contra',
                         'Porc_Tackle_Ganado_a_favor_y':'Porc_Tackle_Ganado_en_contra',
                         'Bloqueos_a_favor_y':'Bloqueos_en_contra',
                         'Tiros_Bloqueos_a_favor_y':'Tiros_Bloqueos_en_contra',
                         'Pases_Bloqueos_a_favor_y':'Pases_Bloqueos_en_contra',
                         'Interceptaciones_a_favor_y':'Interceptaciones_en_contra',
                         'Tackles_Interceptaciones_a_favor_y':'Tackles_Interceptaciones_en_contra',
                         'Despejes_a_favor_y':'Despejes_en_contra',
                         'Errores_equipo_propio_y':'Errores_equipos_rivales',
                         'Tarjetas_Amarillas_equipo_propio_y':'Eliminar_2',
                         'Tarjetas_Rojas_equipo_propio_y':'Eliminar_3',
                         '2_Tarjetas_Amarillas_equipo_propio_y':'2_Tarjetas_Amarillas_equipos_rivales',
                         'Faltas_cometidas_equipo_propio_y':'Faltas_cometidas_equipos_rivales',
                         'Fueras_Juego_equipo_propio_y':'Fueras_Juego_equipos_rivales',
                         'Duelos_Aereos_ganados_equipo_propio_y':'Duelos_Aereos_ganados_equipos_rivales',
                         'Duelos_Aereos_perdidos_equipo_propio_y':'Duelos_Aereos_perdidos_equipos_rivales',
                         'Porc_Duelos_Aereos_ganados_equipo_propio_y':'Porc_Duelos_Aereos_ganados_equipos_rivales'
                         }, inplace=True)
DF_FINAL.drop(columns=['Eliminar_1','Eliminar_2','Eliminar_3'], inplace=True)

# %%
col_Temporada = DF_FINAL.iloc[:, 15]
DF_FINAL.drop(DF_FINAL.columns[15], axis=1, inplace=True)
DF_FINAL.insert(0, 'Temporada', col_Temporada)

# %%
 DF_FINAL.head()
# Out:
#    Temporada  Rk            Squad  MP   W  D  L  GF  GA  GD  Pts  Pts/MP  \
# 0  2023_2024   1      Real Madrid  28  21  6  1  60  18  42   69    2.46
# 1  2023_2024   2           Girona  28  19  5  4  59  33  26   62    2.21
# 2  2023_2024   3        Barcelona  28  18  7  3  57  34  23   61    2.18
# 3  2023_2024   4  Atlético Madrid  28  17  4  7  54  31  23   55    1.96
# 4  2023_2024   5    Athletic Club  28  15  8  5  48  26  22   53    1.89
#
#      xG   xGA   xGD  xGD/90  Rk_Home  Partidos_Home  W_Home  D_Home  L_Home  \
# 0  52.2  26.2  26.0    0.93        1             14      12       2       0
# 1  47.8  38.0   9.8    0.35        2             14      11       2       1
# 2  61.0  29.0  32.0    1.14        3             15      11       1       3
# 3  49.2  29.6  19.6    0.70        4             14      13       1       0
# 4  42.8  27.7  15.1    0.54        5             14      10       3       1
#
# ...

# %%
DF_FINAL.to_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/LALIGA_FBREF_201617_202324_J28.csv', index=False)

# %% [markdown]
# # **3. Junto los datasets por paises**

# %%
DF_LALIGA = pd.read_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/LALIGA_FBREF_201617_202324_J28.csv', sep=',', index_col=False)
DF_PREMIER = pd.read_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/PREMIER_FBREF_201617_202324_J28.csv', sep=',', index_col=False)
DF_SERIEA = pd.read_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/SERIEA_FBREF_201617_202324_J28.csv', sep=',', index_col=False)
DF_BUNDESLIGA = pd.read_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/BUNDESLIGA_FBREF_201617_202324_J28.csv', sep=',', index_col=False)
DF_LIGUE1 = pd.read_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/LIGUE1_FBREF_201617_202324_J28.csv', sep=',', index_col=False)

# %%
DF_LALIGA['COMPETICION'] = 'LALIGA'
DF_PREMIER['COMPETICION'] = 'PREMIER'
DF_SERIEA['COMPETICION'] = 'SERIEA'
DF_BUNDESLIGA['COMPETICION'] = 'BUNDESLIGA'
DF_LIGUE1['COMPETICION'] = 'LIGUE1'

# %%
col_COMPETICION = DF_LALIGA.iloc[:, 353]
DF_LALIGA.drop(DF_LALIGA.columns[353], axis=1, inplace=True)
DF_LALIGA.insert(0, 'Competicion', col_COMPETICION)

col_COMPETICION = DF_PREMIER.iloc[:, 353]
DF_PREMIER.drop(DF_PREMIER.columns[353], axis=1, inplace=True)
DF_PREMIER.insert(0, 'Competicion', col_COMPETICION)

col_COMPETICION = DF_SERIEA.iloc[:, 353]
DF_SERIEA.drop(DF_SERIEA.columns[353], axis=1, inplace=True)
DF_SERIEA.insert(0, 'Competicion', col_COMPETICION)

col_COMPETICION = DF_BUNDESLIGA.iloc[:, 353]
DF_BUNDESLIGA.drop(DF_BUNDESLIGA.columns[353], axis=1, inplace=True)
DF_BUNDESLIGA.insert(0, 'Competicion', col_COMPETICION)

col_COMPETICION = DF_LIGUE1.iloc[:, 353]
DF_LIGUE1.drop(DF_LIGUE1.columns[353], axis=1, inplace=True)
DF_LIGUE1.insert(0, 'Competicion', col_COMPETICION)

# %%
GRANDES_5_LIGAS_EUR_FBREF_201617_202324_J28 = pd.concat([DF_LALIGA,DF_PREMIER,DF_SERIEA,DF_BUNDESLIGA,DF_LIGUE1], ignore_index=True)

# %%
GRANDES_5_LIGAS_EUR_FBREF_201617_202324_J28.to_csv('/content/drive/MyDrive/Master Analisis de datos futbol/Master/Tablas_FBREF/GRANDES_5_LIGAS_EUR_FBREF_201617_202324_J28.csv', sep=',', index=False)

# %%
GRANDES_5_LIGAS_EUR_FBREF_201617_202324_J28
# Out:
#     Competicion  Temporada  Rk            Squad  MP   W   D   L  GF  GA  GD  \
# 0        LALIGA  2023_2024   1      Real Madrid  28  21   6   1  60  18  42
# 1        LALIGA  2023_2024   2           Girona  28  19   5   4  59  33  26
# 2        LALIGA  2023_2024   3        Barcelona  28  18   7   3  57  34  23
# 3        LALIGA  2023_2024   4  Atlético Madrid  28  17   4   7  54  31  23
# 4        LALIGA  2023_2024   5    Athletic Club  28  15   8   5  48  26  22
# ..          ...        ...  ..              ...  ..  ..  ..  ..  ..  ..  ..
# 679      LIGUE1  2017_2018  16             Caen  38  10   8  20  27  52 -25
# 680      LIGUE1  2017_2018  17            Lille  38  10   8  20  41  67 -26
# 681      LIGUE1  2017_2018  18         Toulouse  38   9  10  19  38  54 -16
# 682      LIGUE1  2017_2018  19           Troyes  38   9   6  23  32  59 -27
# 683      LIGUE1  2017_2018  20             Metz  38   6   8  24  34  76 -42
#
# ...
